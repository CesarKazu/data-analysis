# %%
#Analise de dados de celulares roubados registrados 
#pelo departamento da DEINTER de São José dos Campos 
#de Janeiro de 2018 à Abril de 2019.
#Utilizando as informações cedidas pelo portal de transparencia do governo do estado de São Paulo 
#é possivel evidenciar as regiões com maiores indices de roubo de celulares 
#e assim aplicar uma solução de segurança. 
#Projeto elaborado para a materia de Graduação de Projeto de Banco de Dados Não Estruturados na FATEC de São José dos Campos.

import pandas as pd
from pandas import Series, DataFrame
import folium
from folium import plugins
import seaborn as sb
low_memory=False
# %matplotlib inline
pd.options.display.max_columns = 80
pd.options.display.max_rows = 90

# %%
path = 'datasets/'
filenames = {'2018_1', '2018_2', '2018_3', '2018_4', '2018_5', '2018_6', '2018_7', '2018_8', '2018_9', '2018_10', '2018_11', '2018_12', '2019_1', '2019_2', '2019_3', '2019_4'}
extension = '.xls'

# %%
#Função para percorrer os arquivos de dados e popular o dataframe.
def populaDataFrame():
    dfList = list()

    for file in filenames:
        df= pd.DataFrame(pd.read_csv((path+file+extension), sep='\t', encoding='UTF-16 LE'))
        dfList.append(df)

    df = pd.concat(dfList)
    return df

# %%
df = populaDataFrame()
df.reset_index()
df.shape
#Quantidade de linhas e colunas no dataframe.
# Out:
# (11638, 54)

# %%
df.sample(10)
#10 linhhas aleatórias e seus dados.
# Out:
#      ANO_BO   NUM_BO NUMERO_BOLETIM          BO_INICIADO           BO_EMITIDO  \
# 407    2018     4155      4155/2018  22/12/2018 04:39:16  22/12/2018 11:05:25
# 388    2018  1465407   1465407/2018  19/11/2018 01:58:11  19/11/2018 01:58:56
# 526    2018     1200      1200/2018  24/10/2018 15:27:52  24/10/2018 17:55:22
# 271    2019      466       466/2019  11/03/2019 17:07:33  11/03/2019 17:21:48
# 563    2018      515       515/2018  26/11/2018 10:29:36  26/11/2018 11:35:58
# 349    2018     3207      3207/2018  19/09/2018 02:54:53  19/09/2018 05:12:45
# 235    2019     1025      1025/2019  11/04/2019 08:20:18  11/04/2019 08:37:36
# 586    2018      595       595/2018  27/03/2018 10:23:41  27/03/2018 10:46:56
# 285    2018      156       156/2018  14/01/2018 16:05:58  14/01/2018 17:30:36
# 492    2018   959091    959091/2018  22/07/2018 10:04:21  22/07/2018 10:04:31
#
#     DATAOCORRENCIA PERIDOOCORRENCIA DATACOMUNICACAO       DATAELABORACAO  \
# 407     22/12/2018     DE MADRUGADA      22/12/2018  22/12/2018 04:39:16
# 388     15/11/2018          A TARDE      18/11/2018  19/11/2018 01:58:11
# 526     24/10/2018       PELA MANHÃ      24/10/2018  24/10/2018 15:27:52
# 271     11/03/2019          A TARDE      11/03/2019  11/03/2019 17:07:33
# 563     26/11/2018     DE MADRUGADA      26/11/2018  26/11/2018 10:29:36
# 349     19/09/2018     DE MADRUGADA      19/09/2018  19/09/2018 02:54:53
# 235     11/04/2019     DE MADRUGADA      11/04/2019  11/04/2019 08:20:18
# 586     27/03/2018     DE MADRUGADA      27/03/2018  27/03/2018 10:23:41
# 285     14/01/2018       PELA MANHÃ      14/01/2018  14/01/2018 16:05:58
# 492     21/07/2018       PELA MANHÃ      21/07/2018  22/07/2018 10:04:21
#
#        BO_AUTORIA FLAGRANTE NUMERO_BOLETIM_PRINCIPAL  \
# 407     Conhecida       Sim                      NaN
# 388  Desconhecida       Não                      NaN
# 526  Desconhecida       Não                      NaN
# 271  Desconhecida       Não                      NaN
# 563  Desconhecida       Não                      NaN
# 349     Conhecida       Sim                      NaN
# 235  Desconhecida       Não                      NaN
# 586  Desconhecida       Não                      NaN
# 285  Desconhecida       Não                      NaN
# 492  Desconhecida       Não                      NaN
#
#                                    LOGRADOURO  NUMERO  \
# 407                  RUA GOVERNADOR VALADARES   233.0
# 388                          RUA ANGELO FIRMO    15.0
# 526                                       NaN     0.0
# 271                            AVENIDA TIVOLI   111.0
# 563                          AVENIDA SÃO JOSÉ     1.0
# 349                     RUA CARLOS ESPERINDIO    29.0
# 235                              RUA ANCHIETA   114.0
# 586  AVENIDA ENGENHEIRO JUAREZ DE SIQUEIRA BR     1.0
# 285                      RUA ARMANDO DE MOURA    10.0
# 492                             AVENIDA LENIN   218.0
#
#                                        BAIRRO             CIDADE   UF  \
# 407                       JARDIM SANTO ONOFRE  S.JOSE DOS CAMPOS   SP
# 388                                    CENTRO            TAUBATE   SP
# 526                                       NaN                NaN  NaN
# 271                              VILA BETÂNIA  S.JOSE DOS CAMPOS   SP
# 563                                    CENTRO             LORENA   SP
# 349                                VILA ESTER  S.JOSE DOS CAMPOS   SP
# 235                                PONTE ALTA          APARECIDA   SP
# 586  CONJUNTO INDUSTRIAL EMPRESARIAL ELDORADO  S.JOSE DOS CAMPOS   SP
# 285                               AGUA QUENTE            TAUBATE   SP
# 492        CONJUNTO HABITACIONAL DOM PEDRO II  S.JOSE DOS CAMPOS   SP
#
#               LATITUDE          LONGITUDE DESCRICAOLOCAL   EXAME  \
# 407   -23,248680434493  -45,8300972361134    Via pública  IC-IML
# 388         -23,028824         -45,562869    Via Pública     NaN
# 526                NaN                NaN     Residência     NaN
# 271   -23,205736187638  -45,8886372318739    Via pública     NaN
# 563  -22,7343377619999      -45,121754306    Via pública     NaN
# 349     -23,1678103376     -45,8418651056    Via pública  IC-IML
# 235  -22,8459381445205  -45,2317089665205     Hospedagem     NaN
# 586      -23,263817043  -45,9132647769999    Via pública     NaN
# 285  -23,0061585186486  -45,5325361767297    Via pública     IML
# 492                NaN                NaN         Outros     NaN
#
#                             SOLUCAO                  DELEGACIA_NOME  \
# 407               BO PARA FLAGRANTE     DEL.SEC.POL.SJCAMPOS PL SUL
# 388                BO PARA REGISTRO            DELEGACIA ELETRONICA
# 526  APRECIAÇÃO DO DELEGADO TITULAR      04º D.P. S.JOSE DOS CAMPOS
# 271            BO PARA INVESTIGAÇÃO      01º D.P. S.JOSE DOS CAMPOS
# 563  APRECIAÇÃO DO DELEGADO TITULAR                 DEL.POL.PIQUETE
# 349               BO PARA FLAGRANTE  DEL.SEC.POL.SJCAMPOS PL CENTRO
# 235  APRECIAÇÃO DO DELEGADO TITULAR               DEL.POL.APARECIDA
# 586  APRECIAÇÃO DO DELEGADO TITULAR      03º D.P. S.JOSE DOS CAMPOS
# 285  APRECIAÇÃO DO DELEGADO TITULAR         DEL.SEC.TAUBATE PLANTÃO
# 492                BO PARA REGISTRO            DELEGACIA ELETRONICA
#
#         DELEGACIA_CIRCUNSCRICAO                                   ESPECIE  \
# 407  06º D.P. S.JOSE DOS CAMPOS       Título I - Pessoa (arts. 121 a 154)
# 388            01º D.P. TAUBATE  Título II - Patrimônio (arts. 155 a 183)
# 526  04º D.P. S.JOSE DOS CAMPOS  Título II - Patrimônio (arts. 155 a 183)
# 271  01º D.P. S.JOSE DOS CAMPOS  Título II - Patrimônio (arts. 155 a 183)
# 563             02º D.P. LORENA  Título II - Patrimônio (arts. 155 a 183)
# 349  05º D.P. S.JOSE DOS CAMPOS  Título II - Patrimônio (arts. 155 a 183)
# 235           DEL.POL.APARECIDA  Título II - Patrimônio (arts. 155 a 183)
# 586  03º D.P. S.JOSE DOS CAMPOS  Título II - Patrimônio (arts. 155 a 183)
# 285            03º D.P. TAUBATE  Título II - Patrimônio (arts. 155 a 183)
# 492  03º D.P. S.JOSE DOS CAMPOS  Título II - Patrimônio (arts. 155 a 183)
#
#                                           RUBRICA  \
# 407                  Homicídio simples (art. 121)
# 388                     Roubo (art. 157) - OUTROS
# 526                    Roubo (art. 157) - VEICULO
# 271                    Roubo (art. 157) - VEICULO
# 563                 Roubo (art. 157) - TRANSEUNTE
# 349                    Roubo (art. 157) - VEICULO
# 235  Roubo (art. 157) - ESTABELECIMENTO COMERCIAL
# 586                     Roubo (art. 157) - OUTROS
# 285                 Roubo (art. 157) - TRANSEUNTE
# 492                     Roubo (art. 157) - OUTROS
#
#                                          DESDOBRAMENTO     STATUS NOMEPESSOA  \
# 407  Morte decorrente de intervenção policial (RES....    Tentado        NaN
# 388                                                NaN  Consumado        NaN
# 526                                                NaN  Consumado        NaN
# 271                                                NaN  Consumado        NaN
# 563                                                NaN  Consumado        NaN
# 349                                                NaN  Consumado        NaN
# 235                                                NaN  Consumado        NaN
# 586                                                NaN  Consumado        NaN
# 285                                                NaN  Consumado        NaN
# 492                                                NaN  Consumado        NaN
#
#     TIPOPESSOA VITIMAFATAL  RG RG_UF NATURALIDADE NACIONALIDADE SEXO  \
# 407        NaN         NaN NaN   NaN          NaN           NaN  NaN
# 388        NaN         NaN NaN   NaN          NaN           NaN  NaN
# 526        NaN         NaN NaN   NaN          NaN           NaN  NaN
# 271        NaN         NaN NaN   NaN          NaN           NaN  NaN
# 563        NaN         NaN NaN   NaN          NaN           NaN  NaN
# 349        NaN         NaN NaN   NaN          NaN           NaN  NaN
# 235        NaN         NaN NaN   NaN          NaN           NaN  NaN
# 586        NaN         NaN NaN   NaN          NaN           NaN  NaN
# 285        NaN         NaN NaN   NaN          NaN           NaN  NaN
# 492        NaN         NaN NaN   NaN          NaN           NaN  NaN
#
#     DATANASCIMENTO  IDADE ESTADOCIVIL PROFISSAO GRAUINSTRUCAO  CORCUTIS  \
# 407            NaN    NaN         NaN       NaN           NaN       NaN
# 388            NaN    NaN         NaN       NaN           NaN       NaN
# 526            NaN    NaN         NaN       NaN           NaN       NaN
# 271            NaN    NaN         NaN       NaN           NaN       NaN
# 563            NaN    NaN         NaN       NaN           NaN       NaN
# 349            NaN    NaN         NaN       NaN           NaN       NaN
# 235            NaN    NaN         NaN       NaN           NaN       NaN
# 586            NaN    NaN         NaN       NaN           NaN       NaN
# 285            NaN    NaN         NaN       NaN           NaN       NaN
# 492            NaN    NaN         NaN       NaN           NaN       NaN
#
#     NATUREZAVINCULADA TIPOVINCULO PLACA_VEICULO UF_VEICULO  \
# 407               NaN         NaN           NaN        NaN
# 388               NaN         NaN           NaN        NaN
# 526               NaN         NaN           NaN        NaN
# 271               NaN         NaN       FYC6780         SP
# 563               NaN         NaN           NaN        NaN
# 349               NaN         NaN       EFT6562         SP
# 235               NaN         NaN           NaN        NaN
# 586               NaN         NaN           NaN        NaN
# 285               NaN         NaN           NaN        NaN
# 492               NaN         NaN           NaN        NaN
#
#           CIDADE_VEICULO DESCR_COR_VEICULO DESCR_MARCA_VEICULO  \
# 407                  NaN               NaN                 NaN
# 388                  NaN               NaN                 NaN
# 526                  NaN               NaN                 NaN
# 271  SAO JOSE DOS CAMPOS            Branco          BMW/F800 R
# 563                  NaN               NaN                 NaN
# 349  SAO JOSE DOS CAMPOS             Preta       GM/MERIVA JOY
# 235                  NaN               NaN                 NaN
# 586                  NaN               NaN                 NaN
# 285                  NaN               NaN                 NaN
# 492                  NaN               NaN                 NaN
#
#      ANO_FABRICACAO  ANO_MODELO DESCR_TIPO_VEICULO  QUANT_CELULAR  \
# 407             0.0         0.0                NaN            1.0
# 388             0.0         0.0                NaN            NaN
# 526             0.0         0.0                NaN            1.0
# 271          2014.0      2015.0          MOTOCICLO            1.0
# 563             0.0         0.0                NaN            1.0
# 349          2008.0      2008.0          AUTOMOVEL            1.0
# 235             0.0         0.0                NaN            1.0
# 586             0.0         0.0                NaN            1.0
# 285             0.0         0.0                NaN            1.0
# 492             0.0         0.0                NaN            NaN
#
#     MARCA_CELULAR
# 407       SAMSUNG
# 388      MOTOROLA
# 526      Motorola
# 271      Motorola
# 563       Samsung
# 349       Samsung
# 235       Samsung
# 586      Motorola
# 285       Samsung
# 492         APPLE

# %%
df.groupby('PERIDOOCORRENCIA').size().sort_values().plot(kind='pie')
#Gráfico de pizza com os períodos de ocorrência dos roubos de celulares.

# %%
df['PERIDOOCORRENCIA'].value_counts().to_frame()
#Dados quantitativos com os períodos de ocorrência dos roubos de celulares.
# Out:
#                  PERIDOOCORRENCIA
# A NOITE                      5064
# A TARDE                      2631
# PELA MANHÃ                   2206
# DE MADRUGADA                 1688
# EM HORA INCERTA                49

# %%
df.query('CIDADE == "S.JOSE DOS CAMPOS"')['BAIRRO'].value_counts().head(10).plot(kind='barh')
#Gráfico de barras horizontais contendo os bairros de SJC com mais ocorrência dos roubos de celulares.

# %%
df.query('CIDADE == "S.JOSE DOS CAMPOS"')['BAIRRO'].value_counts().to_frame().head(10)
#Dados quantitativos contendo os bairros de SJC com mais ocorrência dos roubos de celulares.
# Out:
#                        BAIRRO
# BOSQUE DOS EUCALIPTOS     159
# CENTRO                    155
# JARDIM SATÉLITE           114
# PARQUE INDUSTRIAL         102
# JARDIM MORUMBI             98
# VISTA VERDE                83
# CHÁCARAS REUNIDAS          80
# EUGÊNIO DE MELO            71
# PARQUE NOVO HORIZONTE      68
# CAMPO DOS ALEMÃES          60

# %%
df.groupby('ANO_BO').size().sort_values().plot(kind='barh')
#Gráfico de barras horizontais contendo a quantidade de BO's por ano de SJC sos roubos de celulares.

# %%
df['ANO_BO'].value_counts().to_frame()
#Dados quantitativos contendo a quantidade de BO's por ano de SJC sos roubos de celulares.
# Out:
#       ANO_BO
# 2018    9034
# 2019    2603
# 2017       1

# %%
df2019_4= pd.DataFrame(pd.read_csv((path+"2019_4"+extension), sep='\t', encoding='UTF-16 LE'))
df2019_4.shape
#Populando o dataframe com o arquivo de dados de 2019-4 e exibindo a quantidade de linhas e colunas.
# Out:
# (623, 54)

# %%
geolocalizacoes = df2019_4[['LATITUDE', 'LONGITUDE', 'PERIDOOCORRENCIA']].copy()
geolocalizacoes.isnull().sum()
#Copiando o dataframe com as informações que iremos utilizar e exibindo a quantidade de campos nulos.
# Out:
# LATITUDE            71
# LONGITUDE           71
# PERIDOOCORRENCIA     0
# dtype: int64

# %%
geolocalizacoes.dropna(inplace=True)
geolocalizacoes.isnull().sum()
#Removendo os campos nulos e exibindo novamente a quantidade de campos nulos.
# Out:
# LATITUDE            0
# LONGITUDE           0
# PERIDOOCORRENCIA    0
# dtype: int64

# %%
coordenadas = []
lat = geolocalizacoes['LATITUDE'].values

long = geolocalizacoes['LONGITUDE'].values

periodo = geolocalizacoes['PERIDOOCORRENCIA'].values

colors = {
 'DE MADRUGADA': 'blue',
 'PELA MANHÃ': 'green',
 'A TARDE': 'orange',
 'A NOITE': 'red',
 'EM HORA INCERTA': 'purple',
}

mapa = folium.Map(location=[-23.1791, -45.8872],tiles='OpenStreetMap',zoom_start=10)
cont = 0
for la,lo,p in zip(lat,long,periodo):
    folium.Marker(
        location=[float(la.replace(",", ".")), float(lo.replace(",", "."))],
        icon=folium.Icon(color=colors[p])
    ).add_to(mapa)

mapa
#Através da biblioteca do Folium criamos um novo mapa, marcamos os roubos de celulares de abril 2019
#com as latitudes e longitudes do dataframe e definimos a cor do marcador através do período de ocorrência.
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
def embed_map(m):
    from IPython.display import HTML

    m.save('index.html')
    with open('index.html') as f:
        html = f.read()

    iframe = '<iframe srcdoc="{srcdoc}" style="width: 100%; height: 750px; border: none"></iframe>'
    srcdoc = html.replace('"', '&quot;')
    return HTML(iframe.format(srcdoc=srcdoc))


embed_map(mapa)
# Out:
# c:\users\cesar\appdata\local\programs\python\python37-32\lib\site-packages\IPython\core\display.py:689: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#     <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#
#         <script>
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         </script>
#
#     <script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.js&quot;></script>
#     <script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;></script>
#     <script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#     <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;></script>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/>
#     <style>html, body {width: 100%;height: 100%;margin: 0;padding: 0;}</style>
#     <style>#map {position:absolute;top:0;bottom:0;right:0;left:0;}</style>
#
#             <meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; />
#             <style>
#                 #map_c487782f5d2f4516bf8459d531ea471e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             </style>
#
# </head>
# <body>
#
#             <div class=&quot;folium-map&quot; id=&quot;map_c487782f5d2f4516bf8459d531ea471e&quot; ></div>
#
# </body>
# <script>
#
#             var map_c487782f5d2f4516bf8459d531ea471e = L.map(
#                 &quot;map_c487782f5d2f4516bf8459d531ea471e&quot;,
#                 {
#                     center: [-23.1791, -45.8872],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0dd4dfd9979048f4842ddf201ad64479 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c487782f5d2f4516bf8459d531ea471e);
#
#
#             var marker_fa14bdabf3ea41d8aa4d755d83922432 = L.marker(
#                 [-23.1684265972631, -45.8362981876842],
#                 {}
#             ).addTo(map_c487782f5d2f4516bf8459d531ea471e);
#
#
#             var icon_8b34fda1141a4400bd420f137d195ff8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fa14bdabf3ea41d8aa4d755d83922432.setIcon(icon_8b34fda1141a4400bd420f137d195ff8);
#
#
#             var marker_8c07790ab9ab44a09492f9221b6a02ed = L.marker(
#                 [-22.799037235, -45.207295481],
#                 {}
#             ).addTo(map_c487782f5d2f4516bf8459d531ea471e);
#
#
#             var icon_d5e5ea4517c645218004f1f09ce578ab = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8c07790ab9ab44a09492f9221b6a02ed.setIcon(icon_d5e5ea4517c645218004f1f09ce578ab);
#
#
#             var marker_61da638cf0b64a2abe1f06f3cb5c7ce2 = L.marker(
#                 [-23.1784776383508, -45.8364501697365],
#                 {}
#             ).addTo(map_c487782f5d2f4516bf8459d531ea471e);
#
#
#             var icon_3fafc0a459b145d48e6268c549ac24d9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_61da638cf0b64a2abe1f06f3cb5c7ce2.setIcon(icon_3fafc0a459b145d48e6268c549ac24d9);
#
#
#             var marker_49d9605378c0442897d15fdd8ead0bb4 = L.marker(
#                 [-22.943747994, -45.4163203919999],
#                 {}
#             ).addTo(map_c487782f5d2f4516bf8459d531ea471e);
#
#
#             var icon_ef4123201e2342ea83ee2bcc44afe65e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_49d9605378c0442897d15fdd8ead0bb4.setIcon(icon_ef4123201e2342ea83ee2bcc44afe65e);
#
#
#             var marker_54a13d75a47d4769baccd7cc48904c5e = L.marker(
#                 [-23.1721709882, -45.8139467164],
#                 {}
#             ).addTo(map_c487782f5d2f4516bf8459d531ea471e);
#
#
#             var icon_e77361857c3c4a0da2c0569af2e3cd22 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_54a13d75a47d4769baccd7cc48904c5e.setIcon(icon_e77361857c3c4a0da2c0569af2e3cd22);
#
#
#             var marker_54b8c95200fa4787b4e2ce751bc6c1ab = L.marker(
#                 [-22.927155886, -45.459700433],
#                 {}
#             ).addTo(map_c487782f5d2f4516bf8459d531ea471e);
#
#
#             var icon_ff86e110d5b44552a00484e79416852e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_54b8c95200fa4787b4e2ce751bc6c1ab.setIcon(icon_ff86e110d5b44552a00484e79416852e);
#
#
#             var marker_01d6495a74c249ae9ab0d1f7da7a6340 = L.marker(
#                 [-22.9053409627814, -45.3730823695847],
#                 {}
#             ).addTo(map_c487782f5d2f4516bf8459d531ea471e);
#
#
#             var icon_0910e382d2c0477b91d39d6e4d7f4524 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_01d6495a74c249ae9ab0d1f7da7a6340.setIcon(icon_0910e382d2c0477b91d39d6e4d7f4524);

# %%
geolocalizacoes = df[['LATITUDE', 'LONGITUDE', 'PERIDOOCORRENCIA']].copy()
geolocalizacoes.isnull().sum()
#Copiando o dataframe com as informações que iremos utilizar e exibindo a quantidade de campos nulos.
# Out:
# LATITUDE            1748
# LONGITUDE           1748
# PERIDOOCORRENCIA       0
# dtype: int64

# %%
geolocalizacoes.dropna(inplace=True)
geolocalizacoes.isnull().sum()
#Removendo os campos nulos e exibindo novamente a quantidade de campos nulos.
# Out:
# LATITUDE            0
# LONGITUDE           0
# PERIDOOCORRENCIA    0
# dtype: int64

# %%
coordenadas = []
lat = geolocalizacoes['LATITUDE'].values

long = geolocalizacoes['LONGITUDE'].values

mapa = folium.Map(location=[-23.1791, -45.8872],tiles='OpenStreetMap',zoom_start=10)
 
for la,lo in zip(lat,long):
    coordenadas.append([float(la.replace(",", ".")),float(lo.replace(",", "."))])
    
mapa.add_child(plugins.HeatMap(coordenadas))
#Através da biblioteca do Folium criamos um novo mapa e populamos ele com as latitudes e longitudes do dataframe
#Utilizando um mapa de calor marcamos os pontos de roubos de celulares de janeiro de 2018 à  abril 2019
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
