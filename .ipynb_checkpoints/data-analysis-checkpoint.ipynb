# %%
#Analise de dados de celulares roubados registrados 
#pelo departamento da DEINTER de São José dos Campos 
#de Janeiro de 2018 à Abril de 2019.
#Utilizando as informações cedidas pelo portal de transparencia do governo do estado de São Paulo 
#é possivel evidenciar as regiões com maiores indices de roubo de celulares 
#e assim aplicar uma solução de segurança. 
#Projeto elaborado para a materia de Graduação de Projeto de Banco de Dados Não Estruturados na FATEC de São José dos Campos.

import pandas as pd
from pandas import Series, DataFrame
import folium
from folium import plugins
import seaborn as sb
low_memory=False
# %matplotlib inline
pd.options.display.max_columns = 80
pd.options.display.max_rows = 90

# %%
path = 'datasets/'
filenames = {'2018_1', '2018_2', '2018_3', '2018_4', '2018_5', '2018_6', '2018_7', '2018_8', '2018_9', '2018_10', '2018_11', '2018_12', '2019_1', '2019_2', '2019_3', '2019_4'}
extension = '.xls'

# %%
#Função para percorrer os arquivos de dados e popular o dataframe.
def populaDataFrame():
    dfList = list()

    for file in filenames:
        df= pd.DataFrame(pd.read_csv((path+file+extension), sep='\t', encoding='UTF-16 LE'))
        dfList.append(df)

    df = pd.concat(dfList)
    return df

# %%
df = populaDataFrame()
df.reset_index()
df.shape
#Quantidade de linhas e colunas no dataframe.
# Out:
# (11638, 54)

# %%
df.sample(10)
#10 linhhas aleatórias e seus dados.
# Out:
#       ANO_BO  NUM_BO NUMERO_BOLETIM          BO_INICIADO           BO_EMITIDO  \
# 350     2019     411       411/2019  19/02/2019 12:39:04  19/02/2019 14:34:43
# 1085    2018     357       357/2018  22/02/2018 20:50:57  22/02/2018 21:41:45
# 141     2019      51        51/2019  07/01/2019 11:12:38  07/01/2019 11:37:45
# 548     2018    2120      2120/2018  17/08/2018 22:37:29  18/08/2018 00:32:05
# 454     2019    2290      2290/2019  23/04/2019 09:26:54  23/04/2019 10:43:58
# 481     2019     683       683/2019  18/03/2019 17:30:22  18/03/2019 18:59:16
# 404     2018     962       962/2018  16/05/2018 12:46:59  16/05/2018 12:55:39
# 357     2018     114       114/2018  15/02/2018 16:41:27  15/02/2018 16:58:14
# 292     2018   61661     61661/2018  15/01/2018 12:20:47  15/01/2018 12:20:47
# 499     2018    1167      1167/2018  16/08/2018 12:54:45  16/08/2018 13:13:02
#
#      DATAOCORRENCIA PERIDOOCORRENCIA DATACOMUNICACAO       DATAELABORACAO  \
# 350      18/02/2019          A NOITE      19/02/2019  19/02/2019 12:39:04
# 1085     22/02/2018          A NOITE      22/02/2018  22/02/2018 20:50:57
# 141      04/01/2019          A NOITE      07/01/2019  07/01/2019 11:12:38
# 548      17/08/2018          A NOITE      17/08/2018  17/08/2018 22:37:29
# 454      22/04/2019          A NOITE      23/04/2019  23/04/2019 09:26:54
# 481      18/03/2019       PELA MANHÃ      18/03/2019  18/03/2019 17:30:22
# 404      15/05/2018          A NOITE      16/05/2018  16/05/2018 12:46:59
# 357      15/02/2018     DE MADRUGADA      15/02/2018  15/02/2018 16:41:27
# 292      14/01/2018       PELA MANHÃ      15/01/2018  15/01/2018 12:20:47
# 499      15/08/2018          A NOITE      16/08/2018  16/08/2018 12:54:45
#
#         BO_AUTORIA FLAGRANTE NUMERO_BOLETIM_PRINCIPAL  \
# 350   Desconhecida       Não                      NaN
# 1085  Desconhecida       Não                      NaN
# 141   Desconhecida       Não                      NaN
# 548   Desconhecida       Não                      NaN
# 454   Desconhecida       Não                      NaN
# 481   Desconhecida       Não                      NaN
# 404   Desconhecida       Não                      NaN
# 357   Desconhecida       Não        111/2018 - 130202
# 292   Desconhecida       Não                      NaN
# 499   Desconhecida       Não       1166/2018 - 130212
#
#                                  LOGRADOURO  NUMERO  \
# 350                           AVENIDA TIMBÓ   102.0
# 1085            RUA ALCIDES DE MELO RAMALHO   270.0
# 141                   RUA EUCLÍDES DA CUNHA     1.0
# 548   RUA ANTONIO CARLOS BETOCINI RODRIGUES    68.0
# 454       RODOVIA PRESIDENTE DUTRA (BR 116)   159.0
# 481                    AVENIDA JOSE SCARPEL     1.0
# 404              RUA SANTO INACIO DE LOYOLA     1.0
# 357                   PRAÇA CÔNEGO SIQUEIRA     1.0
# 292                         RUA JOAO PESSOA   495.0
# 499             PASSAGEM NOEL ALVES NICACIO     1.0
#
#                                BAIRRO             CIDADE  UF  \
# 350                         AEROPORTO            TAUBATE  SP
# 1085  JARDIM RESIDENCIAL DOUTOR LESSA    PINDAMONHANGABA  SP
# 141                             AREAO            TAUBATE  SP
# 548                   JARDIM PEDRAMAR            JACAREI  SP
# 454                   PARQUE MEIA LUA            JACAREI  SP
# 481             PARQUE NOVA ESPERANÇA  S.JOSE DOS CAMPOS  SP
# 404                   JARDIM ORIENTAL  S.JOSE DOS CAMPOS  SP
# 357                     ALTO CRUZEIRO              CUNHA  SP
# 292      VILA NOSSA SENHORA APARECIDA    PINDAMONHANGABA  SP
# 499                            CENTRO             LORENA  SP
#
#                LATITUDE          LONGITUDE       DESCRICAOLOCAL EXAME  \
# 350   -23,0122185325773  -45,5808784464963     Area não ocupada   NaN
# 1085      -22,944102253      -45,478466378          Via pública   NaN
# 141   -23,0124466139999      -45,561712219          Via pública   NaN
# 548   -23,3182243857819  -46,0268322198974  Comércio e serviços   NaN
# 454    -23,264229898395  -45,9573986351568      Rodovia/Estrada   NaN
# 481       -23,198483847      -45,789616278          Via pública   NaN
# 404   -23,2390337419999      -45,899557331          Via pública   NaN
# 357   -23,0804000313499     -44,9613223492          Via pública    IC
# 292   -22,8933797999999      -45,375720594               Outros   NaN
# 499   -22,7343377619999      -45,121754306          Via pública   NaN
#
#                              SOLUCAO              DELEGACIA_NOME  \
# 350             BO PARA INVESTIGAÇÃO            02º D.P. TAUBATE
# 1085  APRECIAÇÃO DO DELEGADO TITULAR       DEL.POL.PLANTÃO PINDA
# 141   APRECIAÇÃO DO DELEGADO TITULAR            02º D.P. TAUBATE
# 548             BO PARA INVESTIGAÇÃO     DEL.SEC.JACAREI PLANTÃO
# 454   ENCAMINHAMENTO DP ÁREA DO FATO               07º D.P. LAPA
# 481   APRECIAÇÃO DO DELEGADO TITULAR  06º D.P. S.JOSE DOS CAMPOS
# 404   APRECIAÇÃO DO DELEGADO TITULAR  03º D.P. S.JOSE DOS CAMPOS
# 357                   BO PARA ADENDO               DEL.POL.CUNHA
# 292                 BO PARA REGISTRO        DELEGACIA ELETRONICA
# 499                   BO PARA ADENDO             02º D.P. LORENA
#
#          DELEGACIA_CIRCUNSCRICAO                                   ESPECIE  \
# 350             02º D.P. TAUBATE  Título II - Patrimônio (arts. 155 a 183)
# 1085     DEL.POL.PINDAMONHANGABA  Título II - Patrimônio (arts. 155 a 183)
# 141             02º D.P. TAUBATE  Título II - Patrimônio (arts. 155 a 183)
# 548             02º D.P. JACAREI                Localização e/ou Devolução
# 454             03º D.P. JACAREI  Título II - Patrimônio (arts. 155 a 183)
# 481   06º D.P. S.JOSE DOS CAMPOS  Título II - Patrimônio (arts. 155 a 183)
# 404   03º D.P. S.JOSE DOS CAMPOS  Título II - Patrimônio (arts. 155 a 183)
# 357                DEL.POL.CUNHA  Título II - Patrimônio (arts. 155 a 183)
# 292     02º D.P. PINDAMONHANGABA  Título II - Patrimônio (arts. 155 a 183)
# 499              02º D.P. LORENA  Título II - Patrimônio (arts. 155 a 183)
#
#                                                 RUBRICA  \
# 350           Roubo (art. 157) - ESTABELECIMENTO-OUTROS
# 1085                         Roubo (art. 157) - VEICULO
# 141                       Roubo (art. 157) - TRANSEUNTE
# 548          Localização/Apreensão e Entrega de veículo
# 454                          Roubo (art. 157) - VEICULO
# 481                          Roubo (art. 157) - VEICULO
# 404                       Roubo (art. 157) - TRANSEUNTE
# 357   Furto qualificado (art. 155, §4o.) - ESTABELEC...
# 292         Roubo (art. 157) - INTERIOR ESTABELECIMENTO
# 499                       Roubo (art. 157) - TRANSEUNTE
#
#                                           DESDOBRAMENTO     STATUS NOMEPESSOA  \
# 350                                                 NaN  Consumado        NaN
# 1085                                                NaN  Consumado        NaN
# 141                                                 NaN  Consumado        NaN
# 548                                                 NaN  Consumado        NaN
# 454   caput. Subtrair coisa móvel alheia, mediante g...  Consumado        NaN
# 481                                                 NaN  Consumado        NaN
# 404                                                 NaN  Consumado        NaN
# 357                         §4o. Se o crime é cometido:  Consumado        NaN
# 292                                                 NaN  Consumado        NaN
# 499                                                 NaN  Consumado        NaN
#
#      TIPOPESSOA VITIMAFATAL  RG RG_UF NATURALIDADE NACIONALIDADE SEXO  \
# 350         NaN         NaN NaN   NaN          NaN           NaN  NaN
# 1085        NaN         NaN NaN   NaN          NaN           NaN  NaN
# 141         NaN         NaN NaN   NaN          NaN           NaN  NaN
# 548         NaN         NaN NaN   NaN          NaN           NaN  NaN
# 454         NaN         NaN NaN   NaN          NaN           NaN  NaN
# 481         NaN         NaN NaN   NaN          NaN           NaN  NaN
# 404         NaN         NaN NaN   NaN          NaN           NaN  NaN
# 357         NaN         NaN NaN   NaN          NaN           NaN  NaN
# 292         NaN         NaN NaN   NaN          NaN           NaN  NaN
# 499         NaN         NaN NaN   NaN          NaN           NaN  NaN
#
#      DATANASCIMENTO  IDADE ESTADOCIVIL PROFISSAO GRAUINSTRUCAO  CORCUTIS  \
# 350             NaN    NaN         NaN       NaN           NaN       NaN
# 1085            NaN    NaN         NaN       NaN           NaN       NaN
# 141             NaN    NaN         NaN       NaN           NaN       NaN
# 548             NaN    NaN         NaN       NaN           NaN       NaN
# 454             NaN    NaN         NaN       NaN           NaN       NaN
# 481             NaN    NaN         NaN       NaN           NaN       NaN
# 404             NaN    NaN         NaN       NaN           NaN       NaN
# 357             NaN    NaN         NaN       NaN           NaN       NaN
# 292             NaN    NaN         NaN       NaN           NaN       NaN
# 499             NaN    NaN         NaN       NaN           NaN       NaN
#
#      NATUREZAVINCULADA TIPOVINCULO PLACA_VEICULO UF_VEICULO  \
# 350                NaN         NaN           NaN        NaN
# 1085               NaN         NaN       GGW0324         SP
# 141                NaN         NaN           NaN        NaN
# 548                NaN         NaN       FLO8117         SP
# 454                NaN         NaN       AQZ2300         PR
# 481                NaN         NaN       HMZ5164         SP
# 404                NaN         NaN           NaN        NaN
# 357                NaN         NaN       KOU8597         SP
# 292                NaN         NaN           NaN        NaN
# 499                NaN         NaN           NaN        NaN
#
#            CIDADE_VEICULO DESCR_COR_VEICULO     DESCR_MARCA_VEICULO  \
# 350                   NaN               NaN                     NaN
# 1085      PINDAMONHANGABA            Branco        HONDA/FIT LX CVT
# 141                   NaN               NaN                     NaN
# 548   SAO JOSE DOS CAMPOS             Preta    CHEVROLET/CLASSIC LS
# 454            CAFELANDIA            Branco       VOLVO/FH 460 6X2T
# 481   SAO JOSE DOS CAMPOS            Branco  FIAT/UNO MILLE ECONOMY
# 404                   NaN               NaN                     NaN
# 357         GUARATINGUETA             Preta            FORD/KA FLEX
# 292                   NaN               NaN                     NaN
# 499                   NaN               NaN                     NaN
#
#       ANO_FABRICACAO  ANO_MODELO DESCR_TIPO_VEICULO  QUANT_CELULAR  \
# 350              0.0         0.0                NaN            1.0
# 1085          2017.0      2017.0          AUTOMOVEL            1.0
# 141              0.0         0.0                NaN            1.0
# 548           2013.0      2014.0          AUTOMOVEL            1.0
# 454           2013.0      2013.0    CAMINHÃO TRATOR            1.0
# 481           2010.0      2011.0          AUTOMOVEL            1.0
# 404              0.0         0.0                NaN            1.0
# 357           2012.0      2013.0          AUTOMOVEL            1.0
# 292              0.0         0.0                NaN            1.0
# 499              0.0         0.0                NaN            1.0
#
#      MARCA_CELULAR
# 350        Samsung
# 1085       SAMSUNG
# 141        Samsung
# 548       Motorola
# 454       Motorola
# 481        Samsung
# 404        Samsung
# 357        Samsung
# 292       Samsung|
# 499       MOTOROLA

# %%
df.groupby('PERIDOOCORRENCIA').size().sort_values().plot(kind='pie')
#Gráfico de pizza com os períodos de ocorrência dos roubos de celulares.

# %%
df['PERIDOOCORRENCIA'].value_counts().to_frame()
#Dados quantitativos com os períodos de ocorrência dos roubos de celulares.
# Out:
#                  PERIDOOCORRENCIA
# A NOITE                      5064
# A TARDE                      2631
# PELA MANHÃ                   2206
# DE MADRUGADA                 1688
# EM HORA INCERTA                49

# %%
df.query('CIDADE == "S.JOSE DOS CAMPOS"')['BAIRRO'].value_counts().head(10).plot(kind='barh')
#Gráfico de barras horizontais contendo os bairros de SJC com mais ocorrência dos roubos de celulares.

# %%
df.query('CIDADE == "S.JOSE DOS CAMPOS"')['BAIRRO'].value_counts().to_frame().head(10)
#Dados quantitativos contendo os bairros de SJC com mais ocorrência dos roubos de celulares.
# Out:
#                        BAIRRO
# BOSQUE DOS EUCALIPTOS     159
# CENTRO                    155
# JARDIM SATÉLITE           114
# PARQUE INDUSTRIAL         102
# JARDIM MORUMBI             98
# VISTA VERDE                83
# CHÁCARAS REUNIDAS          80
# EUGÊNIO DE MELO            71
# PARQUE NOVO HORIZONTE      68
# CAMPO DOS ALEMÃES          60

# %%
df.groupby('ANO_BO').size().sort_values().plot(kind='barh')
#Gráfico de barras horizontais contendo a quantidade de BO's por ano de SJC sos roubos de celulares.

# %%
df['ANO_BO'].value_counts().to_frame()
#Dados quantitativos contendo a quantidade de BO's por ano de SJC sos roubos de celulares.
# Out:
#       ANO_BO
# 2018    9034
# 2019    2603
# 2017       1

# %%
df2019_4= pd.DataFrame(pd.read_csv((path+"2019_4"+extension), sep='\t', encoding='UTF-16 LE'))
df2019_4.shape
#Populando o dataframe com o arquivo de dados de 2019-4 e exibindo a quantidade de linhas e colunas.
# Out:
# (623, 54)

# %%
geolocalizacoes = df2019_4[['LATITUDE', 'LONGITUDE', 'PERIDOOCORRENCIA']].copy()
geolocalizacoes.isnull().sum()
#Copiando o dataframe com as informações que iremos utilizar e exibindo a quantidade de campos nulos.
# Out:
# LATITUDE            71
# LONGITUDE           71
# PERIDOOCORRENCIA     0
# dtype: int64

# %%
geolocalizacoes.dropna(inplace=True)
geolocalizacoes.isnull().sum()
#Removendo os campos nulos e exibindo novamente a quantidade de campos nulos.
# Out:
# LATITUDE            0
# LONGITUDE           0
# PERIDOOCORRENCIA    0
# dtype: int64

# %%
coordenadas = []
lat = geolocalizacoes['LATITUDE'].values

long = geolocalizacoes['LONGITUDE'].values

periodo = geolocalizacoes['PERIDOOCORRENCIA'].values

colors = {
 'DE MADRUGADA': 'blue',
 'PELA MANHÃ': 'green',
 'A TARDE': 'orange',
 'A NOITE': 'red',
 'EM HORA INCERTA': 'purple',
}

mapa = folium.Map(location=[-23.1791, -45.8872],tiles='OpenStreetMap',zoom_start=10)
cont = 0
for la,lo,p in zip(lat,long,periodo):
    folium.Marker(
        location=[float(la.replace(",", ".")), float(lo.replace(",", "."))],
        icon=folium.Icon(color=colors[p])
    ).add_to(mapa)

mapa
#Através da biblioteca do Folium criamos um novo mapa, marcamos os roubos de celulares de abril 2019
#com as latitudes e longitudes do dataframe e definimos a cor do marcador através do período de ocorrência.
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
mapa.save('index.html')

# %%
from IPython.display import HTML
HTML(filename="./index.html")
# Out:
# <!DOCTYPE html>
# <head>
#     <meta http-equiv="content-type" content="text/html; charset=UTF-8" />
#
#         <script>
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         </script>
#
#     <script src="https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.js"></script>
#     <script src="https://code.jquery.com/jquery-1.12.4.min.js"></script>
#     <script src="https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js"></script>
#     <script src="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js"></script>
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.css"/>
#     <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css"/>
#     <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css"/>
#     <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css"/>
#     <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css"/>
#     <link rel="stylesheet" href="https://rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css"/>
#     <style>html, body {width: 100%;height: 100%;margin: 0;padding: 0;}</style>
#     <style>#map {position:absolute;top:0;bottom:0;right:0;left:0;}</style>
#
#             <meta name="viewport" content="width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no" />
#             <style>
#                 #map_99b6bb264fea44d38b14477e493eb8fa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             </style>
#
# </head>
# <body>
#
#             <div class="folium-map" id="map_99b6bb264fea44d38b14477e493eb8fa" ></div>
#
# </body>
# <script>
#
#             var map_99b6bb264fea44d38b14477e493eb8fa = L.map(
#                 "map_99b6bb264fea44d38b14477e493eb8fa",
#                 {
#                     center: [-23.1791, -45.8872],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8c6cbef29d434ffbb1655d05dd5367c7 = L.tileLayer(
#                 "https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png",
#                 {"attribution": "Data by \u0026copy; \u003ca href=\"http://openstreetmap.org\"\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\"http://www.openstreetmap.org/copyright\"\u003eODbL\u003c/a\u003e.", "detectRetina": false, "maxNativeZoom": 18, "maxZoom": 18, "minZoom": 0, "noWrap": false, "opacity": 1, "subdomains": "abc", "tms": false}
#             ).addTo(map_99b6bb264fea44d38b14477e493eb8fa);
#
#
#             var marker_b4b25bf7a1df43649315cfbba8740007 = L.marker(
#                 [-23.1684265972631, -45.8362981876842],
#                 {}
#             ).addTo(map_99b6bb264fea44d38b14477e493eb8fa);
#
#
#             var icon_8c15a417a35345ddab00647ccb24a6e5 = L.AwesomeMarkers.icon(
#                 {"extraClasses": "fa-rotate-0", "icon": "info-sign", "iconColor": "white", "markerColor": "green", "prefix": "glyphicon"}
#             );
#             marker_b4b25bf7a1df43649315cfbba8740007.setIcon(icon_8c15a417a35345ddab00647ccb24a6e5);
#
#
#             var marker_c76f17ba0f264ebdb383d3fa9459f79e = L.marker(
#                 [-22.799037235, -45.207295481],
#                 {}
#             ).addTo(map_99b6bb264fea44d38b14477e493eb8fa);
#
#
#             var icon_1acfcd1775314789a2aaaa725303b10b = L.AwesomeMarkers.icon(
#                 {"extraClasses": "fa-rotate-0", "icon": "info-sign", "iconColor": "white", "markerColor": "red", "prefix": "glyphicon"}
#             );
#             marker_c76f17ba0f264ebdb383d3fa9459f79e.setIcon(icon_1acfcd1775314789a2aaaa725303b10b);
#
#
#             var marker_85b260380fe745eb83bdeb2d531780a1 = L.marker(
#                 [-23.1784776383508, -45.8364501697365],
#                 {}
#             ).addTo(map_99b6bb264fea44d38b14477e493eb8fa);
#
#
#             var icon_8b199e5269af4e28854a8b7a3bfd2835 = L.AwesomeMarkers.icon(
#                 {"extraClasses": "fa-rotate-0", "icon": "info-sign", "iconColor": "white", "markerColor": "orange", "prefix": "glyphicon"}
#             );
#             marker_85b260380fe745eb83bdeb2d531780a1.setIcon(icon_8b199e5269af4e28854a8b7a3bfd2835);
#
#
#             var marker_095f5d05804441d3871573ab57d2767f = L.marker(
#                 [-22.943747994, -45.4163203919999],
#                 {}
#             ).addTo(map_99b6bb264fea44d38b14477e493eb8fa);
#
#
#             var icon_291a8e738a6549129cecb282ce768ba3 = L.AwesomeMarkers.icon(
#                 {"extraClasses": "fa-rotate-0", "icon": "info-sign", "iconColor": "white", "markerColor": "red", "prefix": "glyphicon"}
#             );
#             marker_095f5d05804441d3871573ab57d2767f.setIcon(icon_291a8e738a6549129cecb282ce768ba3);
#
#
#             var marker_936fe304ed6f4e92a050cbd1a2877406 = L.marker(
#                 [-23.1721709882, -45.8139467164],
#                 {}
#             ).addTo(map_99b6bb264fea44d38b14477e493eb8fa);
#
#
#             var icon_63905719564f4821afead33460931753 = L.AwesomeMarkers.icon(
#                 {"extraClasses": "fa-rotate-0", "icon": "info-sign", "iconColor": "white", "markerColor": "green", "prefix": "glyphicon"}
#             );
#             marker_936fe304ed6f4e92a050cbd1a2877406.setIcon(icon_63905719564f4821afead33460931753);
#
#
#             var marker_59eac1ef96db4fbca497734d98b3de8b = L.marker(
#                 [-22.927155886, -45.459700433],
#                 {}
#             ).addTo(map_99b6bb264fea44d38b14477e493eb8fa);
#
#
#             var icon_8013965158ae4dbe9733e915f6115972 = L.AwesomeMarkers.icon(
#                 {"extraClasses": "fa-rotate-0", "icon": "info-sign", "iconColor": "white", "markerColor": "orange", "prefix": "glyphicon"}
#             );
#             marker_59eac1ef96db4fbca497734d98b3de8b.setIcon(icon_8013965158ae4dbe9733e915f6115972);
#
#
#             var marker_db2e449a21b34b8e933a37d6e277aa7e = L.marker(
#                 [-22.9053409627814, -45.3730823695847],
#                 {}
#             ).addTo(map_99b6bb264fea44d38b14477e493eb8fa);
#
#
#             var icon_cde65b005d224acb870cd04da7834d3e = L.AwesomeMarkers.icon(
#                 {"extraClasses": "fa-rotate-0", "icon": "info-sign", "iconColor": "white", "markerColor": "green", "prefix": "glyphicon"}
#             );
#             marker_db2e449a21b34b8e933a37d6e277aa7e.setIcon(icon_cde65b005d224acb870cd04da7834d3e);
#
#
#             var marker_7a8778b63a9546e19da1d814e4806350 = L.marker(
#                 [-23.1699623549999, -45.835584462],
#                 {}
#             ).addTo(map_99b6bb264fea44d38b14477e493eb8fa);
#
#
#             var icon_cbbcbea957064c05b6bd3d269508073b = L.AwesomeMarkers.icon(
#                 {"extraClasses": "fa-rotate-0", "icon": "info-sign", "iconColor": "white", "markerColor": "green", "prefix": "glyphicon"}
#             );
#             marker_7a8778b63a9546e19da1d814e4806350.setIcon(icon_cbbcbea957064c05b6bd3d269508073b);
#
#
#             var marker_bb60bc98e1ff47e5ab0863895b97dd0b = L.marker(
#                 [-23.1699623549999, -45.835584462],
#                 {}
#             ).addTo(map_99b6bb264fea44d38b14477e493eb8fa);
#
#
#             var icon_e0cb05ee03f24e57ae909e2c21cbd7b2 = L.AwesomeMarkers.icon(
#                 {"extraClasses": "fa-rotate-0", "icon": "info-sign", "iconColor": "white", "markerColor": "green", "prefix": "glyphicon"}
#             );
#             marker_bb60bc98e1ff47e5ab0863895b97dd0b.setIcon(icon_e0cb05ee03f24e57ae90

# %%
geolocalizacoes = df[['LATITUDE', 'LONGITUDE', 'PERIDOOCORRENCIA']].copy()
geolocalizacoes.isnull().sum()
#Copiando o dataframe com as informações que iremos utilizar e exibindo a quantidade de campos nulos.

# %%
geolocalizacoes.dropna(inplace=True)
geolocalizacoes.isnull().sum()
#Removendo os campos nulos e exibindo novamente a quantidade de campos nulos.

# %%
coordenadas = []
lat = geolocalizacoes['LATITUDE'].values

long = geolocalizacoes['LONGITUDE'].values

mapa = folium.Map(location=[-23.1791, -45.8872],tiles='OpenStreetMap',zoom_start=10)
 
for la,lo in zip(lat,long):
    coordenadas.append([float(la.replace(",", ".")),float(lo.replace(",", "."))])
    
mapa.add_child(plugins.HeatMap(coordenadas))
#Através da biblioteca do Folium criamos um novo mapa e populamos ele com as latitudes e longitudes do dataframe
#Utilizando um mapa de calor marcamos os pontos de roubos de celulares de janeiro de 2018 à  abril 2019
