# %%
#Analise de dados de celulares roubados registrados 
#pelo departamento da DEINTER de São José dos Campos 
#de Janeiro de 2018 à Abril de 2019.
#Utilizando as informações cedidas pelo portal de transparencia do governo do estado de São Paulo 
#é possivel evidenciar as regiões com maiores indices de roubo de celulares 
#e assim aplicar uma solução de segurança. 
#Projeto elaborado para a materia de Graduação de Projeto de Banco de Dados Não Estruturados na FATEC de São José dos Campos.

import pandas as pd
from pandas import Series, DataFrame
import folium
from folium import plugins
import seaborn as sb
low_memory=False
# %matplotlib inline
pd.options.display.max_columns = 80
pd.options.display.max_rows = 90

# %%
path = 'datasets/'
filenames = {'2018_1', '2018_2', '2018_3', '2018_4', '2018_5', '2018_6', '2018_7', '2018_8', '2018_9', '2018_10', '2018_11', '2018_12', '2019_1', '2019_2', '2019_3', '2019_4'}
extension = '.xls'

# %%
#Função para percorrer os arquivos de dados e popular o dataframe.
def populaDataFrame():
    dfList = list()

    for file in filenames:
        df= pd.DataFrame(pd.read_csv((path+file+extension), sep='\t', encoding='UTF-16 LE'))
        dfList.append(df)

    df = pd.concat(dfList)
    return df

# %%
df = populaDataFrame()
df.reset_index()
df.shape
#Quantidade de linhas e colunas no dataframe.
# Out:
# (11638, 54)

# %%
df.sample(10)
#10 linhhas aleatórias e seus dados.
# Out:
#      ANO_BO   NUM_BO NUMERO_BOLETIM          BO_INICIADO           BO_EMITIDO  \
# 474    2018      588       588/2018  15/08/2018 16:12:03  15/08/2018 16:40:54
# 220    2018     5178      5178/2018  13/12/2018 11:12:59  13/12/2018 11:30:44
# 606    2018  1380354   1380354/2018  29/10/2018 09:12:57  29/10/2018 09:12:54
# 576    2018     4346      4346/2018  27/11/2018 09:23:20  27/11/2018 09:59:31
# 56     2019       31        31/2019  02/01/2019 22:53:25  03/01/2019 07:36:02
# 364    2018     1800      1800/2018  19/09/2018 15:13:14  19/09/2018 16:43:10
# 306    2018      637       637/2018  16/03/2018 08:59:24  16/03/2018 09:12:44
# 65     2018   157334    157334/2018  04/02/2018 09:19:10  04/02/2018 09:19:10
# 404    2018      217       217/2018  18/04/2018 12:30:30  18/04/2018 13:58:10
# 145    2018      840       840/2018  08/03/2018 23:03:56  08/03/2018 23:36:44
#
#     DATAOCORRENCIA PERIDOOCORRENCIA DATACOMUNICACAO       DATAELABORACAO  \
# 474     15/08/2018       PELA MANHÃ      15/08/2018  15/08/2018 16:12:03
# 220     12/12/2018          A NOITE      13/12/2018  13/12/2018 11:12:59
# 606     28/10/2018       PELA MANHÃ      29/10/2018  29/10/2018 09:12:57
# 576     25/11/2018          A NOITE      27/11/2018  27/11/2018 09:23:20
# 56      02/01/2019          A NOITE      02/01/2019  02/01/2019 22:53:25
# 364     19/09/2018       PELA MANHÃ      19/09/2018  19/09/2018 15:13:14
# 306     14/03/2018          A NOITE      16/03/2018  16/03/2018 08:59:24
# 65      03/02/2018          A NOITE      04/02/2018  04/02/2018 09:19:10
# 404     17/04/2018          A NOITE      18/04/2018  18/04/2018 12:30:30
# 145     08/03/2018          A NOITE      08/03/2018  08/03/2018 23:03:56
#
#        BO_AUTORIA FLAGRANTE NUMERO_BOLETIM_PRINCIPAL  \
# 474  Desconhecida       Não                      NaN
# 220  Desconhecida       Não                      NaN
# 606  Desconhecida       Não                      NaN
# 576  Desconhecida       Não                      NaN
# 56      Conhecida       Sim                      NaN
# 364  Desconhecida       Não                      NaN
# 306  Desconhecida       Não        630/2018 - 130324
# 65   Desconhecida       Não                      NaN
# 404     Conhecida       Não                      NaN
# 145  Desconhecida       Não                      NaN
#
#                             LOGRADOURO  NUMERO  \
# 474                 RUA SHIGEMASA OTTA   639.0
# 220            AVENIDA DERVAL TEIXEIRA   100.0
# 606  AVENIDA EZEQUIEL DA SILVA BARRETO  1420.0
# 576                      RUA NAZARENOS     1.0
# 56                   RUA DOS FERREIROS    59.0
# 364                    RODOVIA SP 099B     2.0
# 306             ESTRADA DO MATO DENTRO   350.0
# 65                 RUA ANTÔNIO CACHUTÉ     0.0
# 404                                NaN     0.0
# 145     TRAVESSA ALCILIO JOSE DE SOUSA     2.0
#
#                                 BAIRRO             CIDADE   UF  \
# 474  CONJUNTO RESIDENCIAL SOL NASCENTE  S.JOSE DOS CAMPOS   SP
# 220                             CENTRO      CARAGUATATUBA   SP
# 606                  JARDIM PORTO NOVO      CARAGUATATUBA   SP
# 576                           UMUARAMA            UBATUBA   SP
# 56               PARQUE NOVO HORIZONTE  S.JOSE DOS CAMPOS   SP
# 364               JARDIM TERRAS DO SUL  S.JOSE DOS CAMPOS   SP
# 306               JARDIM NOVA MICHIGAN  S.JOSE DOS CAMPOS   SP
# 65                         VILA PINHAL            JACAREI   SP
# 404                                NaN                NaN  NaN
# 145                     VILA VENEZIANI  S.JOSE DOS CAMPOS   SP
#
#               LATITUDE          LONGITUDE DESCRICAOLOCAL   EXAME  \
# 474  -23,2453135879999  -45,8927788089999    Via pública     NaN
# 220  -23,6181418011504  -45,4165824842293    Via pública     NaN
# 606                NaN                NaN    Via Pública     NaN
# 576      -23,432648456  -45,0831197099999    Via pública     IML
# 56   -23,1979849307733    -45,78833933568    Via pública  IC-IML
# 364  -23,2465142789999  -45,8902399519999    Via pública     NaN
# 306  -23,1884238812607  -45,7963523101321    Via pública     NaN
# 65       -23,311518145      -45,964266347         Outros     NaN
# 404                NaN                NaN     Residência     NaN
# 145  -23,1499637869999      -45,904642254    Via pública     NaN
#
#                             SOLUCAO                  DELEGACIA_NOME  \
# 474  ENCAMINHAMENTO DP ÁREA DO FATO      08º D.P. S.JOSE DOS CAMPOS
# 220  APRECIAÇÃO DO DELEGADO TITULAR           DEL.POL.CARAGUATATUBA
# 606                BO PARA REGISTRO            DELEGACIA ELETRONICA
# 576            BO PARA INVESTIGAÇÃO                 DEL.POL.UBATUBA
# 56                BO PARA FLAGRANTE     DEL.SEC.POL.SJCAMPOS PL SUL
# 364  ENCAMINHAMENTO DP ÁREA DO FATO        03º D.P. MOGI DAS CRUZES
# 306                  BO PARA ADENDO      06º D.P. S.JOSE DOS CAMPOS
# 65                 BO PARA REGISTRO            DELEGACIA ELETRONICA
# 404  APRECIAÇÃO DO DELEGADO TITULAR                 DEL.POL.IGARATA
# 145  ENCAMINHAMENTO DP ÁREA DO FATO  DEL.SEC.POL.SJCAMPOS PL CENTRO
#
#         DELEGACIA_CIRCUNSCRICAO                                   ESPECIE  \
# 474  03º D.P. S.JOSE DOS CAMPOS                Localização e/ou Devolução
# 220       DEL.POL.CARAGUATATUBA  Título II - Patrimônio (arts. 155 a 183)
# 606       DEL.POL.CARAGUATATUBA  Título II - Patrimônio (arts. 155 a 183)
# 576             DEL.POL.UBATUBA  Título II - Patrimônio (arts. 155 a 183)
# 56   06º D.P. S.JOSE DOS CAMPOS                           L 8069/90 - ECA
# 364  03º D.P. S.JOSE DOS CAMPOS  Título II - Patrimônio (arts. 155 a 183)
# 306  06º D.P. S.JOSE DOS CAMPOS  Título II - Patrimônio (arts. 155 a 183)
# 65             03º D.P. JACAREI  Título II - Patrimônio (arts. 155 a 183)
# 404             DEL.POL.IGARATA  Título II - Patrimônio (arts. 155 a 183)
# 145  04º D.P. S.JOSE DOS CAMPOS  Título II - Patrimônio (arts. 155 a 183)
#
#                                                RUBRICA DESDOBRAMENTO  \
# 474         Localização/Apreensão e Entrega de veículo           NaN
# 220                      Roubo (art. 157) - TRANSEUNTE           NaN
# 606                          Roubo (art. 157) - OUTROS           NaN
# 576                      Roubo (art. 157) - TRANSEUNTE           NaN
# 56   Caput Corromper ou facilitar a corrupção de me...           NaN
# 364                          Roubo (art. 157) - OUTROS           NaN
# 306                      Roubo (art. 157) - TRANSEUNTE           NaN
# 65                       Roubo (art. 157) - TRANSEUNTE           NaN
# 404                         Roubo (art. 157) - VEICULO           NaN
# 145                         Roubo (art. 157) - VEICULO           NaN
#
#         STATUS NOMEPESSOA TIPOPESSOA VITIMAFATAL  RG RG_UF NATURALIDADE  \
# 474  Consumado        NaN        NaN         NaN NaN   NaN          NaN
# 220  Consumado        NaN        NaN         NaN NaN   NaN          NaN
# 606  Consumado        NaN        NaN         NaN NaN   NaN          NaN
# 576  Consumado        NaN        NaN         NaN NaN   NaN          NaN
# 56   Consumado        NaN        NaN         NaN NaN   NaN          NaN
# 364  Consumado        NaN        NaN         NaN NaN   NaN          NaN
# 306  Consumado        NaN        NaN         NaN NaN   NaN          NaN
# 65   Consumado        NaN        NaN         NaN NaN   NaN          NaN
# 404  Consumado        NaN        NaN         NaN NaN   NaN          NaN
# 145  Consumado        NaN        NaN         NaN NaN   NaN          NaN
#
#     NACIONALIDADE SEXO DATANASCIMENTO  IDADE ESTADOCIVIL PROFISSAO  \
# 474           NaN  NaN            NaN    NaN         NaN       NaN
# 220           NaN  NaN            NaN    NaN         NaN       NaN
# 606           NaN  NaN            NaN    NaN         NaN       NaN
# 576           NaN  NaN            NaN    NaN         NaN       NaN
# 56            NaN  NaN            NaN    NaN         NaN       NaN
# 364           NaN  NaN            NaN    NaN         NaN       NaN
# 306           NaN  NaN            NaN    NaN         NaN       NaN
# 65            NaN  NaN            NaN    NaN         NaN       NaN
# 404           NaN  NaN            NaN    NaN         NaN       NaN
# 145           NaN  NaN            NaN    NaN         NaN       NaN
#
#     GRAUINSTRUCAO  CORCUTIS NATUREZAVINCULADA TIPOVINCULO PLACA_VEICULO  \
# 474           NaN       NaN               NaN         NaN       FGW6615
# 220           NaN       NaN               NaN         NaN           NaN
# 606           NaN       NaN               NaN         NaN           NaN
# 576           NaN       NaN               NaN         NaN           NaN
# 56            NaN       NaN               NaN         NaN           NaN
# 364           NaN       NaN               NaN         NaN           NaN
# 306           NaN       NaN               NaN         NaN           NaN
# 65            NaN       NaN               NaN         NaN           NaN
# 404           NaN       NaN               NaN         NaN       ELB6602
# 145           NaN       NaN               NaN         NaN       ESM5027
#
#     UF_VEICULO       CIDADE_VEICULO DESCR_COR_VEICULO  \
# 474         SP  SAO JOSE DOS CAMPOS             Prata
# 220        NaN                  NaN               NaN
# 606        NaN                  NaN               NaN
# 576        NaN                  NaN               NaN
# 56         NaN                  NaN               NaN
# 364        NaN                  NaN               NaN
# 306        NaN                  NaN               NaN
# 65         NaN                  NaN               NaN
# 404         SP              IGARATA          Vermelho
# 145         SP    S.JOSE DOS CAMPOS             Preta
#
#          DESCR_MARCA_VEICULO  ANO_FABRICACAO  ANO_MODELO DESCR_TIPO_VEICULO  \
# 474  FIAT/UNO ATTRACTIVE 1.0          2014.0      2015.0          AUTOMOVEL
# 220                      NaN             0.0         0.0                NaN
# 606                      NaN             0.0         0.0                NaN
# 576                      NaN             0.0         0.0                NaN
# 56                       NaN             0.0         0.0                NaN
# 364                      NaN             0.0         0.0                NaN
# 306                      NaN             0.0         0.0                NaN
# 65                       NaN             0.0         0.0                NaN
# 404    VW/GOLF 1.6 SPORTLINE          2009.0      2010.0          AUTOMOVEL
# 145       JTA/SUZUKI GSR150I          2012.0      2012.0          MOTOCICLO
#
#      QUANT_CELULAR MARCA_CELULAR
# 474            1.0       Samsung
# 220            1.0       Samsung
# 606            NaN       SAMSUNG
# 576            1.0        Outros
# 56             1.0       Samsung
# 364            1.0       Alcatel
# 306            1.0      MOTOROLA
# 65             1.0     Samsung |
# 404            1.0       Samsung
# 145            1.0       Samsung

# %%
df.groupby('PERIDOOCORRENCIA').size().sort_values().plot(kind='pie')
#Gráfico de pizza com os períodos de ocorrência dos roubos de celulares.

# %%
df['PERIDOOCORRENCIA'].value_counts().to_frame()
#Dados quantitativos com os períodos de ocorrência dos roubos de celulares.
# Out:
#                  PERIDOOCORRENCIA
# A NOITE                      5064
# A TARDE                      2631
# PELA MANHÃ                   2206
# DE MADRUGADA                 1688
# EM HORA INCERTA                49

# %%
df.query('CIDADE == "S.JOSE DOS CAMPOS"')['BAIRRO'].value_counts().head(10).plot(kind='barh')
#Gráfico de barras horizontais contendo os bairros de SJC com mais ocorrência dos roubos de celulares.

# %%
df.query('CIDADE == "S.JOSE DOS CAMPOS"')['BAIRRO'].value_counts().to_frame().head(10)
#Dados quantitativos contendo os bairros de SJC com mais ocorrência dos roubos de celulares.
# Out:
#                        BAIRRO
# BOSQUE DOS EUCALIPTOS     159
# CENTRO                    155
# JARDIM SATÉLITE           114
# PARQUE INDUSTRIAL         102
# JARDIM MORUMBI             98
# VISTA VERDE                83
# CHÁCARAS REUNIDAS          80
# EUGÊNIO DE MELO            71
# PARQUE NOVO HORIZONTE      68
# CAMPO DOS ALEMÃES          60

# %%
df.groupby('ANO_BO').size().sort_values().plot(kind='barh')
#Gráfico de barras horizontais contendo a quantidade de BO's por ano de SJC sos roubos de celulares.

# %%
df['ANO_BO'].value_counts().to_frame()
#Dados quantitativos contendo a quantidade de BO's por ano de SJC sos roubos de celulares.
# Out:
#       ANO_BO
# 2018    9034
# 2019    2603
# 2017       1

# %%
df2019_4= pd.DataFrame(pd.read_csv((path+"2019_4"+extension), sep='\t', encoding='UTF-16 LE'))
df2019_4.shape
#Populando o dataframe com o arquivo de dados de 2019-4 e exibindo a quantidade de linhas e colunas.
# Out:
# (623, 54)

# %%
geolocalizacoes = df2019_4[['LATITUDE', 'LONGITUDE', 'PERIDOOCORRENCIA']].copy()
geolocalizacoes.isnull().sum()
#Copiando o dataframe com as informações que iremos utilizar e exibindo a quantidade de campos nulos.
# Out:
# LATITUDE            71
# LONGITUDE           71
# PERIDOOCORRENCIA     0
# dtype: int64

# %%
geolocalizacoes.dropna(inplace=True)
geolocalizacoes.isnull().sum()
#Removendo os campos nulos e exibindo novamente a quantidade de campos nulos.
# Out:
# LATITUDE            0
# LONGITUDE           0
# PERIDOOCORRENCIA    0
# dtype: int64

# %%
coordenadas = []
lat = geolocalizacoes['LATITUDE'].values

long = geolocalizacoes['LONGITUDE'].values

periodo = geolocalizacoes['PERIDOOCORRENCIA'].values

colors = {
 'DE MADRUGADA': 'blue',
 'PELA MANHÃ': 'green',
 'A TARDE': 'orange',
 'A NOITE': 'red',
 'EM HORA INCERTA': 'purple',
}

mapa = folium.Map(location=[-23.1791, -45.8872],tiles='OpenStreetMap',zoom_start=10)
cont = 0
for la,lo,p in zip(lat,long,periodo):
    folium.Marker(
        location=[float(la.replace(",", ".")), float(lo.replace(",", "."))],
        icon=folium.Icon(color=colors[p])
    ).add_to(mapa)

mapa
#Através da biblioteca do Folium criamos um novo mapa, marcamos os roubos de celulares de abril 2019
#com as latitudes e longitudes do dataframe e definimos a cor do marcador através do período de ocorrência.
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from IPython.display import HTML, display
#mapa._build_map()
mapa._repr_html_()
html_string = mapa._repr_html_()
print("%html", html_string)
#mapa.get_root().render()
mapWidth, mapHeight = (400,500) # width and height of the displayed iFrame, in pixels
#srcdoc = mapa.HTML.replace('"', '&quot;')
srcdoc = mapa
width, height = 650, 500
embed = HTML('<iframe srcdoc="{}" '
             'style="width: {}px; height: {}px; display:block; width: 50%; margin: 0 auto; '
             'border: none"></iframe>'.format(srcdoc, width, height))
display(embed)
# Out:
# %html <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
# <iframe srcdoc="<folium.folium.Map object at 0x00000291EB1E14A8>" style="width: 650px; height: 500px; display:block; width: 50%; margin: 0 auto; border: none"></iframe>

# %%
geolocalizacoes = df[['LATITUDE', 'LONGITUDE', 'PERIDOOCORRENCIA']].copy()
geolocalizacoes.isnull().sum()
#Copiando o dataframe com as informações que iremos utilizar e exibindo a quantidade de campos nulos.
# Out:
# LATITUDE            1748
# LONGITUDE           1748
# PERIDOOCORRENCIA       0
# dtype: int64

# %%
geolocalizacoes.dropna(inplace=True)
geolocalizacoes.isnull().sum()
#Removendo os campos nulos e exibindo novamente a quantidade de campos nulos.
# Out:
# LATITUDE            0
# LONGITUDE           0
# PERIDOOCORRENCIA    0
# dtype: int64

# %%
coordenadas = []
lat = geolocalizacoes['LATITUDE'].values

long = geolocalizacoes['LONGITUDE'].values

mapa = folium.Map(location=[-23.1791, -45.8872],tiles='OpenStreetMap',zoom_start=10)
 
for la,lo in zip(lat,long):
    coordenadas.append([float(la.replace(",", ".")),float(lo.replace(",", "."))])
    
mapa.add_child(plugins.HeatMap(coordenadas))
#Através da biblioteca do Folium criamos um novo mapa e populamos ele com as latitudes e longitudes do dataframe
#Utilizando um mapa de calor marcamos os pontos de roubos de celulares de janeiro de 2018 à  abril 2019
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
